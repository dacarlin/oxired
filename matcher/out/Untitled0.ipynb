# %%
import matplotlib.pyplot as plt
from core import enzdes_score
sf = enzdes_score.read_scorefile('score.sc')
sf['scaffold'] = sf['description'].str[0:4]
# %matplotlib inline
plt.figure()
sf.describe
# Out:
# <bound method DataFrame.describe of       total_score  fa_rep  hbond_sc  all_cst  tot_pstat_pm  tot_nlpstat_pm  \
# 0         -859.31  105.02    -28.09    27.30          0.59            0.60
# 1        -1038.02   91.57    -31.76    83.55          0.59            0.58
# 2         -814.65  107.96    -26.98    35.85          0.61            0.61
# 3         -872.28   89.88    -16.21    69.60          0.54            0.52
# 4         -866.77  103.36    -27.41    32.38          0.62            0.60
# 5         -866.96  103.28    -27.35    36.41          0.60            0.59
# 6         -871.60  102.38    -27.44    25.56          0.62            0.60
# 7         -865.62  106.80    -27.38    87.89          0.57            0.60
# 8        -1516.81  160.15    -43.07    87.14          0.62            0.64
# 9        -1144.08  128.11    -30.69    70.58          0.63            0.63
# 10       -1148.70  120.55    -30.32    96.93          0.66            0.64
# ...
